# %% [markdown]
# <a href="https://colab.research.google.com/github/altn714/ESAA/blob/main/genre_%26_distribution_EDA_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### 장르별 영화 관객수 평균값으로 랭크 인코딩

# %%
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import KFold
from ngboost import NGBRegressor

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(train)
plt.show()
#dir_prev_bfnum, dir_prev_num, num_staff, num_actor, box_off_num

# %%
#각자 배급사의 히스토그램
sns.countplot(y = 'distributor', data = train)

# %%
#배급사의 빈도수 계산해서 오름차순
train.loc[:,["distributor"]].value_counts().sort_values()
# Out:
# distributor
# 위더스필름           1
# ()더픽쳐스          1
# 키노엔터테인먼트        1
# 크리에이티브컴즈()      1
# 콘텐츠판다           1
#                ..
# 쇼박스            28
# 마운틴픽처스         30
# ()NEW          30
# 롯데엔터테인먼트       52
# CJ             68
# Length: 152, dtype: int64

# %%
# 관객수 빈도 수의 히스토그램
sns.countplot(y = train.loc[:,["distributor"]].value_counts().sort_values(), data = train)

# %%
#각 장르의 히스토그램
#train.loc[:,["genre"]]
sns.countplot(y = 'genre', data = train)

# %%
#장르 별 관객 수의 박스플랏
sns.boxenplot(x='genre', y='box_off_num', data=train)

# %%
#배급사 별 관객 수의 박스플랏
sns.boxenplot(x='distributor', y='box_off_num', data=train)
