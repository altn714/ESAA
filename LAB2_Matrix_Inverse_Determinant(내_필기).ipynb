# %% [markdown]
# <a href="https://colab.research.google.com/github/altn714/ESAA/blob/main/LAB2_Matrix_Inverse_Determinant(%EB%82%B4_%ED%95%84%EA%B8%B0).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter 2:Determinant and Inverse Matrix

# %%
import numpy as np
import scipy.linalg as la

# %%
#2.2.9 EX
A= np.array( [[1,1,0], 
              [1,1,1], 
              [0,2,1]])
A
# Out:
# array([[1, 1, 0],
#        [1, 1, 1],
#        [0, 2, 1]])

# %%
np.linalg.det(A) #np안 linear algebra 안 det 있음
# Out:
# -2.0

# %%
B = np.linalg.inv(A)

# %%
A@B #inverse 확인
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### Inverse
#
# We can find the inverse using the function `scipy.linalg.inv`:

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
print(la.det(A))
print(la.inv(A))
# Out:
# -2.0
# [[ 0.5  0.5 -0.5]
#  [ 0.5 -0.5  0.5]
#  [-1.   1.   0. ]]

# %% [markdown]
# ### Trace
#
# We can find the trace of a matrix using the function `numpy.trace`:

# %%
np.trace(A) #행렬 대각선의 합
# Out:
# 5

# %% [markdown]
# ### Determinant
#
# We find the determinant using the function `scipy.linalg.det`:

# %%
A = np.array([[1,2],[3,4]])
print(A)
# Out:
# [[1 2]
#  [3 4]]

# %%
la.det(A)
# Out:
# -2.0

# %% [markdown]
# ## Examples
#
# ### Characteristic Polynomials and Cayley-Hamilton Theorem
#
# The characteristic polynomial of a 2 by 2 square matrix $A$ is
#
# $$
# p_A(\lambda) = \det(A - \lambda I) = \lambda^2 - \mathrm{tr}(A) \lambda + \mathrm{det}(A)
# $$
#
# The [Cayley-Hamilton Theorem](https://en.wikipedia.org/wiki/Cayley%E2%80%93Hamilton_theorem) states that any square matrix satisfies its characteristic polynomial. For a matrix $A$ of size 2, this means that
#
# $$
# p_A(A) = A^2 - \mathrm{tr}(A) A + \mathrm{det}(A) I = 0
# $$
#
# Let's verify the Cayley-Hamilton Theorem for a few different matrices.

# %% [markdown]
# 람다 값 given

# %%
# 첫번째 식 등식 성립 확인
## 좌항 
I = np.eye(2)
lambda_= 3.0 #given

la.det(A-lambda_*I)
# Out:
# -8.0

# %%
## 우항
lambda_**2 - np.trace(A)*lambda_ +la.det(A)
# Out:
# -8.0

# %%
trace_A = np.trace(A)
det_A = la.det(A)
I = np.eye(2)
A @ A - trace_A * A + det_A * I
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
N = np.random.randint(0,10,[2,2])
print(N)
# Out:
# [[4 9]
#  [6 0]]

# %%
trace_N = np.trace(N)
det_N = la.det(N)
I = np.eye(2)
N @ N - trace_N * N + det_N * I
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %% [markdown]
# # Example: Permutation
#
# You are given the following permutation
#
# $$
# \sigma = \begin{bmatrix} 1 & 2 & \cdots & n \\\ a_1 & a_2 & \cdots & a_n  \end{bmatrix}
# $$
# For $a=(a_1, a_2, \cdots, a_n)$, write a function which return $\sigma(i)$ with input $a$ and $i$.

# %% [markdown]
# ![KakaoTalk_20230405_133609656.jpg](data:image/jpeg;base64,...)

# %%
def sigma(inp1,inp2):
  return inp1[inp2-1]

# %%
a=np.array([1,3,4,2])
sigma(a,2)
# Out:
# 3

# %% [markdown]
# # Example: cyclic permutation
#
# You are given the following cyclic permutation
# $$ \sigma = (b_1, b_2, \cdots, b_r). $$
# Write a function which return $\sigma(i)$  with input $b:=(b_1, \cdots, b_r)$ and $i$.

# %% [markdown]
# ![dd.jpg](data:image/jpeg;base64,...)

# %%
#인간
def cyc(b,i):
  if i 가 b에 들어있는지?
  ind=(i가 b의 몇번째에 들어있어?)
  ret = B[i%3]+1
  else:
    ret = i

#파이썬
##교수님이 코드 답 알려주심.
